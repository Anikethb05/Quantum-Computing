# %% [markdown]
# <a href="https://colab.research.google.com/github/Anikethb05/Quantum-Computing/blob/main/Lab_1_FQC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit qiskit-aer pylatexenc
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 66.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 105.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 91.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.3 MB/s eta 0:00:00
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=46b833d09cf305eb38f6a0f5d5a6f2bd2393f021b7a92b2abc64deeb4aec213f
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# ...

# %%
from qiskit import QuantumRegister, ClassicalRegister,QuantumCircuit
from qiskit.visualization import plot_histogram, plot_bloch_multivector
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector

# %%
QR056=QuantumRegister(1,'Q')
CR056=ClassicalRegister(1,'C')

QC056=QuantumCircuit(QR056,CR056)

# QC056=QuantumCircuit(1,1)

# %%
state = Statevector.from_instruction(QC056)
plot_bloch_multivector(state)

# %%
QC056.measure_all()

QC056.draw()
# Out:
#          ░ ┌─┐
#      Q: ─░─┤M├
#          ░ └╥┘
#    C: 1/════╬═
#             ║
# meas: 1/════╩═
#             0

# %%
Simulator=AerSimulator()
Job=Simulator.run(QC056)
Counts=Job.result().get_counts()
plot_histogram(Counts, title='Aniketh Bhargav(1RVU23CSE056)')

# %% [markdown]
# Circuit 1

# %%
QR056=QuantumRegister(1,'Q')
CR056=ClassicalRegister(1,'C')

QC056=QuantumCircuit(QR056,CR056)

# QC056=QuantumCircuit(1,1)

# %%
#To convert the state of the first qubit to |1>
#QC056.x(QR056[0])

#To get a superposition
QC056.h(QR056[0])

# %%
state = Statevector.from_instruction(QC056)
plot_bloch_multivector(state)

# %%
QC056.measure_all()
#QC056.draw()
QC056.draw('mpl')

# %%
Simulator=AerSimulator()
Job=Simulator.run(QC056)
Counts=Job.result().get_counts()
plot_histogram(Counts, title='Aniketh Bhargav(1RVU23CSE056)')

# %% [markdown]
# Circuit 2

# %%
QR056=QuantumRegister(1,'Q')
CR056=ClassicalRegister(1,'C')

QC056=QuantumCircuit(QR056,CR056)

# QC056=QuantumCircuit(1,1)

# %%
QC056.x(QR056[0])
QC056.h(QR056[0])

state = Statevector.from_instruction(QC056)
plot_bloch_multivector(state)

# %%
QC056.measure_all()
#QC056.draw()
QC056.draw('mpl')

# %%
Simulator=AerSimulator()
Job=Simulator.run(QC056)
Counts=Job.result().get_counts()
plot_histogram(Counts, title='Aniketh Bhargav(1RVU23CSE056)')

# %% [markdown]
# Circuit 3

# %%
QR056=QuantumRegister(1,'Q')
CR056=ClassicalRegister(1,'C')

QC056=QuantumCircuit(QR056,CR056)

# QC056=QuantumCircuit(1,1)

# %%
QC056.y(QR056[0])

state = Statevector.from_instruction(QC056)
plot_bloch_multivector(state)

# %%
QC056.measure_all()
#QC056.draw()
QC056.draw('mpl')

# %%
Simulator=AerSimulator()
Job=Simulator.run(QC056)
Counts=Job.result().get_counts()
plot_histogram(Counts, title='Aniketh Bhargav(1RVU23CSE056)')

# %% [markdown]
# Circuit 4

# %%
QR056=QuantumRegister(1,'Q')
CR056=ClassicalRegister(1,'C')

QC056=QuantumCircuit(QR056,CR056)

# QC=QuantumCircuit(1,1)

# %%
QC056.x(QR056[0])
QC056.y(QR056[0])
state = Statevector.from_instruction(QC056)
plot_bloch_multivector(state)

# %%
QC056.measure_all()
#QC.draw()
QC056.draw('mpl')

# %%
Simulator=AerSimulator()
Job=Simulator.run(QC056)
Counts=Job.result().get_counts()
plot_histogram(Counts, title="Aniketh Bhargav (1RVU23CSE056)")

# %% [markdown]
# Circuit 5

# %%
QR056=QuantumRegister(1,'Q')
CR056=ClassicalRegister(1,'C')

QC056=QuantumCircuit(QR056,CR056)

# QC=QuantumCircuit(1,1)

# %%
QC056.x(QR056[0])
state = Statevector.from_instruction(QC056)
plot_bloch_multivector(state)

# %%
QC056.measure_all()
#QC.draw()
QC056.draw('mpl')

# %%
Simulator=AerSimulator()
Job=Simulator.run(QC056)
Counts=Job.result().get_counts()
plot_histogram(Counts, title="Aniketh Bhargav (1RVU23CSE056)")

# %% [markdown]
# Circuit 6

# %%
QR056=QuantumRegister(1,'Q')
CR056=ClassicalRegister(1,'C')

QC056=QuantumCircuit(QR056,CR056)

# QC=QuantumCircuit(1,1)

# %%
QC056.x(QR056[0])
QC056.x(QR056[0])
state = Statevector.from_instruction(QC056)
plot_bloch_multivector(state)

# %%
QC056.measure_all()
#QC.draw()
QC056.draw('mpl')

# %%
Simulator=AerSimulator()
Job=Simulator.run(QC056)
Counts=Job.result().get_counts()
plot_histogram(Counts, title="Aniketh Bhargav (1RVU23CSE056)")

# %% [markdown]
# Circuit 7

# %%
QR056=QuantumRegister(1,'Q')
CR056=ClassicalRegister(1,'C')

QC056=QuantumCircuit(QR056,CR056)

# QC=QuantumCircuit(1,1)

# %%
QC056.z(QR056[0])
state = Statevector.from_instruction(QC056)
plot_bloch_multivector(state)

# %%
QC056.measure_all()
#QC.draw()
QC056.draw('mpl')

# %%
Simulator=AerSimulator()
Job=Simulator.run(QC056)
Counts=Job.result().get_counts()
plot_histogram(Counts, title="Aniketh Bhargav (1RVU23CSE056)")

# %% [markdown]
# Circuit 8

# %%
QR056=QuantumRegister(1,'Q')
CR056=ClassicalRegister(1,'C')

QC056=QuantumCircuit(QR056,CR056)

# QC=QuantumCircuit(1,1)

# %%
QC056.x(QR056[0])
QC056.z(QR056[0])
state = Statevector.from_instruction(QC056)
plot_bloch_multivector(state)

# %%
QC056.measure_all()
#QC.draw()
QC056.draw('mpl')

# %%
Simulator=AerSimulator()
Job=Simulator.run(QC056)
Counts=Job.result().get_counts()
plot_histogram(Counts, title="Aniketh Bhargav (1RVU23CSE056)")

# %% [markdown]
# Circuit 9

# %%
QR056=QuantumRegister(1,'Q')
CR056=ClassicalRegister(1,'C')

QC056=QuantumCircuit(QR056,CR056)

# QC=QuantumCircuit(1,1)

# %%
import math
QC056.p(math.pi/2,QR056[0])
state = Statevector.from_instruction(QC056)
plot_bloch_multivector(state)

# %%
QC056.measure_all()
#QC.draw()
QC056.draw('mpl')

# %%
Simulator=AerSimulator()
Job=Simulator.run(QC056)
Counts=Job.result().get_counts()
plot_histogram(Counts, title="Aniketh Bhargav (1RVU23CSE056)")

# %% [markdown]
# Circuit 10

# %%
QR056=QuantumRegister(1,'Q')
CR056=ClassicalRegister(1,'C')

QC056=QuantumCircuit(QR056,CR056)

# QC=QuantumCircuit(1,1)

# %%
QC056.x(QR056[0])
QC056.p(math.pi/2,QR056[0])
state = Statevector.from_instruction(QC056)
plot_bloch_multivector(state)

# %%
QC056.measure_all()
#QC.draw()
QC056.draw('mpl')

# %%
Simulator=AerSimulator()
Job=Simulator.run(QC056)
Counts=Job.result().get_counts()
plot_histogram(Counts, title="Aniketh Bhargav (1RVU23CSE056)")
