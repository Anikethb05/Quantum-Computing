# %% [markdown]
# <a href="https://colab.research.google.com/github/Anikethb05/Quantum-Computing/blob/main/Interference_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit qiskit-aer pylatexenc

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_histogram
from numpy import pi
from IPython.display import display

# %%
phi_values=[0,pi/4, pi/2, 3*pi/4, pi, 5*pi/4, 3*pi/2, 7*pi/4, 2*pi]

# %%
simulator=AerSimulator()

# %% [markdown]
# ## Michelson's Interferometer

# %%
for phi in phi_values:
  QC=QuantumCircuit(1)
  QC.h(0)
  QC.p(phi,0)
  QC.h(0)
  display(QC.draw('mpl'))

  QC.measure_all()

  result=simulator.run(QC).result()
  count=result.get_counts()
  display(plot_histogram(count))

# %% [markdown]
# ## Mach-Zehnder Interferometer

# %%
for phi in phi_values:
  QC=QuantumCircuit(1)
  QC.h(0)
  QC.p(phi,0)
  QC.h(0)

  display(QC.draw('mpl'))

  QC.measure_all()

  result=simulator.run(QC).result()
  count=result.get_counts()
  display(plot_histogram(count))
