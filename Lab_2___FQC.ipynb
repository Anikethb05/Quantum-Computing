# %% [markdown]
# <a href="https://colab.research.google.com/github/Anikethb05/Quantum-Computing/blob/main/Lab_2___FQC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #!pip install qiskit qiskit-aer pylatexenc

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit.visualization import plot_histogram, plot_bloch_multivector
from qiskit.quantum_info import Statevector
from qiskit_aer import AerSimulator
from matplotlib import pyplot
from numpy import pi,exp,sqrt
import numpy as np

# %% [markdown]
# ## Circuit 1

# %%
QC=QuantumCircuit(2)

# %%
State1=Statevector(QC)
plot_bloch_multivector(State1)
#pyplot.show()

# %%
QC.h(0)
State2=Statevector(QC)
plot_bloch_multivector(State2)

# %%
QC.x(1)
State3=Statevector(QC)
plot_bloch_multivector(State3)

# %%
State3.draw('latex') # Qiskit gives in reverse
# Out:
# $$\frac{\sqrt{2}}{2} |10\rangle+\frac{\sqrt{2}}{2} |11\rangle$$

# %%
QC.measure_all()

# %%
QC.draw('mpl',reverse_bits=True)

# %%
Simulator=AerSimulator()
Job=Simulator.run(QC)
Counts=Job.result().get_counts()
plot_histogram(Counts)

# %% [markdown]
# ## Circuit 2

# %%
QC=QuantumCircuit(2)

# %%
QC.h(0)
State4=Statevector(QC)
plot_bloch_multivector(State4)

# %%
QC.cx(0,1)
State5=Statevector(QC)
plot_bloch_multivector(State5)

# %% [markdown]
# Entangled States

# %%
State5.draw('latex')
# Out:
# $$\frac{\sqrt{2}}{2} |00\rangle+\frac{\sqrt{2}}{2} |11\rangle$$

# %%
QC.measure_all()
QC.draw('mpl',reverse_bits=True)

# %%
Job=Simulator.run(QC)
Counts=Job.result().get_counts()
plot_histogram(Counts)

# %% [markdown]
# ## Circuit 3

# %%
QC=QuantumCircuit(2)

# %%
QC.x(0)
QC.h(0)

# %%
QC.barrier()
# Out:
# CircuitInstruction(operation=Instruction(name='barrier', num_qubits=2, num_clbits=0, params=[]), qubits=(<Qubit register=(2, "q"), index=0>, <Qubit register=(2, "q"), index=1>), clbits=())

# %%
QC.y(1)
QC.x(1)
QC.h(1)

# %%
State6=Statevector(QC)
plot_bloch_multivector(State6)

# %%
QC.cx(0,1)
State7=Statevector(QC)
plot_bloch_multivector(State7)

# %%
State7.draw('latex')
# Out:
# $$\frac{i}{2} |00\rangle- \frac{i}{2} |01\rangle+\frac{i}{2} |10\rangle- \frac{i}{2} |11\rangle$$

# %%
QC.measure_all()
QC.draw('mpl',reverse_bits=True)

# %%
Job=Simulator.run(QC)
Counts=Job.result().get_counts()
plot_histogram(Counts)
