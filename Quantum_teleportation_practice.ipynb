# %% [markdown]
# <a href="https://colab.research.google.com/github/Anikethb05/Quantum-Computing/blob/main/Quantum_teleportation_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit qiskit-aer pylatexenc

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
from qiskit.quantum_info import Statevector
import numpy as np

# %%
QC=QuantumCircuit(3,3)

# %%
QC.initialize([1/np.sqrt(8), np.sqrt(7)/np.sqrt(8)], 0)

# %%
state0= Statevector(QC)

# %%
state0.draw('latex')
# Out:
# $$\frac{\sqrt{2}}{4} |000\rangle+\frac{\sqrt{14}}{4} |001\rangle$$

# %%
QC.h(1)
QC.cx(1,2)
QC.draw()
# Out:
#      ┌─────────────────────────────┐
# q_0: ┤ Initialize(0.35355,0.93541) ├─────
#      └────────────┬───┬────────────┘
# q_1: ─────────────┤ H ├───────────────■──
#                   └───┘             ┌─┴─┐
# q_2: ───────────────────────────────┤ X ├
#                                     └───┘
# c: 3/════════════════════════════════════

# %%
QC.draw('mpl')

# %%
state1=Statevector(QC)

# %%
state1.draw('latex')
# Out:
# $$\frac{1}{4} |000\rangle+\frac{\sqrt{7}}{4} |001\rangle+\frac{1}{4} |110\rangle+\frac{\sqrt{7}}{4} |111\rangle$$

# %%
QC.cx(0,1)
QC.h(0)

# %%
QC.draw('mpl')

# %%
state2=Statevector(QC)

# %%
state2.draw('latex')
# Out:
# $$0.1767766953 |000\rangle+0.1767766953 |001\rangle+0.4677071733 |010\rangle-0.4677071733 |011\rangle+0.4677071733 |100\rangle-0.4677071733 |101\rangle+0.1767766953 |110\rangle+0.1767766953 |111\rangle$$

# %%
QC.measure([0,1],[0,1])

# %%
simulator=AerSimulator()

# %%
result=simulator.run(QC, shots=1024).result()
counts=result.get_counts()
plot_histogram(counts)

# %%
with QC.if_test( (QC.clbits[1],1)):
  QC.x(2)

# %%
with QC.if_test( (QC.clbits[0],1)):
  QC.z(2)

# %%
QC.measure(2,2)

# %%
QC.draw('mpl')

# %%
result1=simulator.run(QC).result()
count1=result1.get_counts()
plot_histogram(count1)
