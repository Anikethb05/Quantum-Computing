# %% [markdown]
# <a href="https://colab.research.google.com/github/Anikethb05/Quantum-Computing/blob/main/Deutsch_Jozsa_algorithm_1RVU23CSE056.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## FoQC Lab 2025-10-08
# ## Deutsch-Jozsa algorithm
# ### Aniketh Bhargav
# ### 1RVU23CSE056

# %%
# !pip install qiskit qiskit-aer pylatexenc
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 92.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 118.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 113.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 5.1 MB/s eta 0:00:00
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=0c0fb88e7866e0dee079aa804ffcf05ac2e0c33dc16a847a3a229be5a174656f
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# ...

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector, plot_histogram
import matplotlib.pyplot as plt
import numpy as np

# %%
def create_oracle_instruction(oracle_type):
    oracle_circuit = QuantumCircuit(2)
    if oracle_type == 'constant_0':
        oracle_circuit.id(1)
        oracle_circuit.z(1)
    elif oracle_type == 'constant_1':
        oracle_circuit.x(1)
        oracle_circuit.z(1)
    elif oracle_type == 'balanced_0':
        oracle_circuit.cx(0, 1)
        oracle_circuit.z(1)
    elif oracle_type == 'balanced_1':
        oracle_circuit.cx(0, 1)
        oracle_circuit.x(1)
        oracle_circuit.z(1)
    else:
        raise("oracle_type should be one of 'constant_0', 'constant_1', 'balanced_0' or 'balanced_1'")
    return oracle_circuit.to_instruction(label='f-box')

# %%
# circuit 1: constant_0
QC_075 = QuantumCircuit(2, 1)

QC_075.x(0)
QC_075.x(1)

QC_075.h(0)
QC_075.h(1)

QC_075.barrier()

# Apply the custom oracle instruction
oracle_instruction = create_oracle_instruction('constant_0')
QC_075.append(oracle_instruction, [0, 1])

QC_075.barrier()

QC_075.cx(0, 1)

QC_075.h(0)
QC_075.draw('mpl')

# %%
state = Statevector(QC_075)
plot_bloch_multivector(state)

# %%
from qiskit import transpile

QC_075.measure(0,0)
Simulator=AerSimulator()

# Transpile the circuit to the simulator's basis gates
transpiled_qc = transpile(QC_075, Simulator)

job=Simulator.run(transpiled_qc)
result=job.result()
counts=result.get_counts()
plot_histogram(counts)

# %%
# circuit 1: constant_1
QC_075 = QuantumCircuit(2, 1)

QC_075.x(0)
QC_075.x(1)

QC_075.h(0)
QC_075.h(1)

QC_075.barrier()

# Apply the custom oracle instruction
oracle_instruction = create_oracle_instruction('constant_1')
QC_075.append(oracle_instruction, [0, 1])

QC_075.barrier()

QC_075.cx(0, 1)

QC_075.h(0)
QC_075.draw('mpl')

# %%
state = Statevector(QC_075)
plot_bloch_multivector(state)

# %%
QC_075.measure(0,0)
Simulator=AerSimulator()

# Transpile the circuit to the simulator's basis gates
transpiled_qc = transpile(QC_075, Simulator)

job=Simulator.run(transpiled_qc)
result=job.result()
counts=result.get_counts()
plot_histogram(counts)

# %%
# circuit 1: balanced_0
QC_075 = QuantumCircuit(2, 1)

QC_075.x(0)
QC_075.x(1)

QC_075.h(0)
QC_075.h(1)

QC_075.barrier()

# Apply the custom oracle instruction
oracle_instruction = create_oracle_instruction('balanced_0')
QC_075.append(oracle_instruction, [0, 1])

QC_075.barrier()

QC_075.cx(0, 1)

QC_075.h(0)
QC_075.draw('mpl')

# %%
state = Statevector(QC_075)
plot_bloch_multivector(state)

# %%
QC_075.measure(0,0)
Simulator=AerSimulator()

# Transpile the circuit to the simulator's basis gates
transpiled_qc = transpile(QC_075, Simulator)

job=Simulator.run(transpiled_qc)
result=job.result()
counts=result.get_counts()
plot_histogram(counts)

# %%
# circuit 1: balanced_1
QC_075 = QuantumCircuit(2, 1)

QC_075.x(0)
QC_075.x(1)

QC_075.h(0)
QC_075.h(1)

QC_075.barrier()

# Apply the custom oracle instruction
oracle_instruction = create_oracle_instruction('balanced_1')
QC_075.append(oracle_instruction, [0, 1])

QC_075.barrier()

QC_075.cx(0, 1)

QC_075.h(0)
QC_075.draw('mpl')

# %%
state = Statevector(QC_075)
plot_bloch_multivector(state)

# %%
QC_075.measure(0,0)
Simulator=AerSimulator()

# Transpile the circuit to the simulator's basis gates
transpiled_qc = transpile(QC_075, Simulator)

job=Simulator.run(transpiled_qc)
result=job.result()
counts=result.get_counts()
plot_histogram(counts)
