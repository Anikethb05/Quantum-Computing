# %% [markdown]
# <a href="https://colab.research.google.com/github/Anikethb05/Quantum-Computing/blob/main/Classical_Gates_using_Quantum_Circuits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Aniketh Bhargav
# USN: 1RVU23CSE056

# %%
#!pip install qiskit qiskit-aer pylatexenc

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector, plot_histogram
from qiskit_aer import AerSimulator
from matplotlib import pyplot
from numpy import pi, exp, sqrt
import numpy as np

# %%
Simulator=AerSimulator()

# %% [markdown]
# ## AND

# %%
QC=QuantumCircuit(3)

# %%
QC.h(0)
QC.h(1)
QC.ccx(0,1,2)

# %%
QC.measure_all()
job = Simulator.run(QC)
results = job.result().get_counts()
QC.draw('mpl')

# %%
plot_histogram(results)

# %% [markdown]
# ## XOR

# %%
QC=QuantumCircuit(3)

# %%
QC.h(0)
QC.h(1)
QC.cx(0,2)
QC.cx(1,2)

# %%
QC.measure_all()
job = Simulator.run(QC)
results = job.result().get_counts()
QC.draw('mpl')

# %%
plot_histogram(results)

# %% [markdown]
# ## OR

# %%
QC=QuantumCircuit(3)

# %%
QC.h(0)
QC.h(1)
QC.cx(0,2)
QC.cx(1,2)
QC.ccx(0,1,2)

# %%
QC.measure_all()
job=Simulator.run(QC)
results=job.result().get_counts()
QC.draw('mpl')

# %%
plot_histogram(results)

# %% [markdown]
# ## HALF-ADDER

# %%
QC=QuantumCircuit(4)

# %%
QC.h(0)
QC.h(1)
QC.cx(0,2)
QC.cx(1,2)
QC.ccx(0,1,3)

# %%
QC.measure_all()
job=Simulator.run(QC)
results=job.result().get_counts()
QC.draw('mpl')

# %%
plot_histogram(results)

# %% [markdown]
# ## HALF-ADDED (3-Qubits)

# %%
QC=QuantumCircuit(3)

# %%
QC.h(0)
QC.h(1)
QC.ccx(0,1,2)
QC.cx(0,1)

# %%
QC.measure_all()
job=Simulator.run(QC)
results=job.result().get_counts()
QC.draw('mpl')

# %%
plot_histogram(results)

# %% [markdown]
# ## FULL-ADDER

# %%
QC=QuantumCircuit(5)

# %%
QC.h(0)
QC.h(1)
QC.h(2)
QC.cx(0,3)
QC.cx(1,3)
QC.cx(2,3)
QC.ccx(0,1,4)
QC.ccx(1,2,4)
QC.ccx(0,2,4)

# %%
QC.measure_all()
job=Simulator.run(QC)
results=job.result().get_counts()
QC.draw('mpl')

# %%
plot_histogram(results)

# %% [markdown]
# ## FULL-ADDER (4-qubit)

# %%
QC=QuantumCircuit(4)

# %%
QC.h(0)
QC.h(1)
QC.h(2)
QC.ccx(0,1,3)
QC.ccx(1,2,3)
QC.ccx(0,2,3)
QC.cx(0,2)
QC.cx(1,2)
# QC.cx(0,2)

# %%
QC.measure_all()
job=Simulator.run(QC)
results=job.result().get_counts()
QC.draw('mpl')

# %%
plot_histogram(results)
